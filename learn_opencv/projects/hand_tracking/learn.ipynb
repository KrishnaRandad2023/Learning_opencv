# %%
import cv2
import mediapipe as mp
import time 
import pyautogui

# screen_width,screen_height = pyautogui.size()

cap = cv2.VideoCapture(0)

mpHands = mp.solutions.hands

hands = mpHands.Hands(
        static_image_mode=False,
        max_num_hands=10,
        min_detection_confidence=0.5,
        min_tracking_confidence = 0.8
  ) #takes defalult parameters #only uses rgb images
mpDraw  = mp.solutions.drawing_utils

previous_time = 0
current_time = 0


while(True):
  success, img  = cap.read()
  # img = cv2.resize(img,(screen_width,screen_height))
  img_rgb = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
  
  results = hands.process(img_rgb)
  print(results.multi_hand_landmarks)
  # for hand in results:
  if results.multi_hand_landmarks :
      # hand_Count = len(results.multi_hand_landmarks)
      
      # cv2.putText(img,str(hand_Count),(100,100),cv2.FONT_HERSHEY_SCRIPT_SIMPLEX,3,(255,0,0),3)
      
      
      # print("the number of hands are ",hand_Count)
      for hand in results.multi_hand_landmarks:
        
        for id,lm in enumerate(hand.landmark):
          print(id,lm)
          h,w,c = img.shape
          cx,cy = int(lm.x * w),int(lm.y * h)
          # print(cx,cy)
          
          # if id==5 :
          
          #   cv2.circle(img,(cx,cy),25,(0,0,255),cv2.FILLED)
        #   if id == 9:  # Base of middle finger
        #         base_x, base_y = cx, cy
        #   if id == 12:  # Tip of middle finger
        #         tip_x, tip_y = cx, cy
        #   if id == 11:  # Middle finger joint
        #         joint_x, joint_y = cx, cy
        # if tip_y < base_y and joint_y < base_y:
        #     middle_finger_raised = True
        # if middle_finger_raised:
        #     cv2.putText(img, "Middle Finger Raised", (50, 50), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 3)
        # # mpDraw.draw_landmarks(img, hand, mpHands.HAND_CONNECTIONS)
                
        
    
        mpDraw.draw_landmarks(img, hand,mpHands.HAND_CONNECTIONS) #hand represents single hand
        #for draing connections
      
  current_time = time.time()
  fps = 1/(current_time - previous_time)
  previous_time = current_time
  
  cv2.putText(img,str(int(fps)),(10,60),cv2.FONT_HERSHEY_COMPLEX,2,(0,255,0),5)
  cv2.imshow('Image',img)
  if cv2.waitKey(1)==ord('q'):
    break
  
cap.release()
cv2.destroyAllWindows()
# Out:
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# [landmark {
#   x: 0.901062965
#   y: 0.699707091
#   z: 6.18171669e-007
# }
# landmark {
#   x: 0.832424164
#   y: 0.678628445
#   z: -0.037660215
# }
# landmark {
#   x: 0.77146703
#   y: 0.60547632
#   z: -0.0547254868
# }
# landmark {
#   x: 0.736065567
#   y: 0.535169244
#   z: -0.0671093687
# }
# landmark {
#   x: 0.713489056
#   y: 0.473359436
#   z: -0.0792597
# }
# landmark {
#   x: 0.809794664
#   y: 0.460300595
#   z: -0.0352250859
# }
# landmark {
#   x: 0.783893228
#   y: 0.359364182
#   z: -0.0609011762
# }
# landmark {
#   x: 0.770937681
#   y: 0.292186797
#   z: -0.0826996416
# }
# landmark {
#   x: 0.763744771
#   y: 0.234996572
#   z: -0.0983502418
# }
# landmark {
#   x: 0.862190425
#   y: 0.438612819
#   z: -0.0349856727
# }
# landmark {
#   x: 0.85192728
# ...
